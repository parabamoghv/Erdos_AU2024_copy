# %% [markdown]
# # Problem Session 12
# ## Neural Networks

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import tensorflow as tf
import keras
from keras import layers

# %% [markdown]
# ### Carseats Regression Problem

# %% [markdown]
# First run the following code to clean the data.

# %%
cars = pd.read_csv("../../Data/car_sales.csv")
cars.dropna(inplace = True)

def clean_column(text):
    return float(text.split()[0])

## Cleaning the mileage, engine and max_power columns
cars['mileage'] = cars['mileage'].apply(clean_column)
cars['engine'] = cars['engine'].apply(clean_column)
cars['max_power'] = cars['max_power'].apply(clean_column)

## creating the age column
cars['age'] = 2020 - cars['year']

## performing the log transform on selling_price and km_driven
cars['log_sell'] = np.log10(cars['selling_price'])
cars['log_km'] = np.log10(cars['km_driven'])

## making one-hot encoded variables for transmission, dealer and owner
cars['automatic'] = 1
cars.loc[cars.transmission=='Manual', 'automatic'] = 0

cars[['first_owner', 'second_owner', 'third_owner']] = pd.get_dummies(cars['owner'])[['First Owner', 
                                                                                      'Second Owner',
                                                                                      'Third Owner']]

cars['dealer'] = 1
cars.loc[cars.seller_type == 'Individual', 'dealer'] = 0

# %%
from sklearn.model_selection import train_test_split

# %%
cars_train, cars_test = train_test_split(cars.copy(),
                                            test_size=.2,
                                            shuffle=True,
                                            random_state=440)

# %%
# Remind yourself about what the data looks like.

features = ['max_power', 'age', 'engine', 'log_km', 'seats', 'dealer', 'automatic', 'mileage']
            
target = ['log_sell']

cars_train[features + target].sample(10)
# Out:
#       max_power  age  engine    log_km  seats  dealer  automatic  mileage  \
# 3707      79.40    8  1199.0  4.778151    5.0       0          0    18.60
# 6750      68.10    7  1399.0  4.397940    5.0       0          0    20.00
# 4991     120.00    3  2179.0  4.903090    7.0       0          0    15.40
# 1764      67.05    4  1364.0  5.161368    5.0       0          0    23.59
# 3851      88.76    6  1248.0  4.176091    7.0       0          0    20.77
# 2497      73.94    4  1248.0  4.778151    5.0       0          0    23.20
# 6500      98.63    2  1498.0  4.633468    5.0       0          0    27.40
# 58       138.03    2  1798.0  4.397940    5.0       1          1    14.28
# 5687      65.00    9  1172.0  4.845098    5.0       0          0    16.50
# 3789      88.50    3  1248.0  4.819544    7.0       0          0    24.52
#
#       log_sell
# 3707  5.255273
# 6750  5.397940
# 4991  5.949878
# 1764  5.755875
# 3851  5.653213
# 2497  5.602060
# 6500  5.845098
# 58    6.201397
# 5687  5.176091
# 3789  5.892095

# %%
# Convert everything to numpy arrays

X_train = cars_train[features].values
y_train = cars_train[target].values
X_test = cars_test[features].values
y_test = cars_test[target].values
X_tt, X_val, y_tt, y_val = train_test_split(X_train, y_train, test_size = 0.2)

# %% [markdown]
# Train a vanilla linear regression model on `(X_tt, y_tt)`.

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_tt,y_tt)
# Out:
# LinearRegression()

# %% [markdown]
# Now try to train a feed forward neural network which has better validation MSE.
#
# Some things to consider:
# * How will you address normalization of the input data, if at all?
# * How many intermediate layers will you use?  What dimensions will they be?
# * What activation functions should you use in the hidden layer?
# * What final activation function should you use, if any?
# * What loss function should you use?
# * What are some other hyperparameters you could play with?
#
# If you are not able to beat linear regression after playing for 20 minutes you should move on.  If you successfully train a neural network and observe the loss going down: count this as a victory!
#
# We will use [early stopping callback](https://keras.io/api/callbacks/early_stopping/).

# %%
model = keras.Sequential([
    layers.InputLayer(X_train.shape[1]),
    layers.BatchNormalization(axis = -1),
    layers.Dense(10, activation = 'relu'),
    layers.Dense(1) 
])

callback = keras.callbacks.EarlyStopping(monitor='loss', patience=3)

model.compile(optimizer = "adam", loss = "mse")

history = model.fit(X_tt, y_tt, epochs = 500, validation_data = (X_val, y_val), batch_size = 32, callbacks=[callback])
# Out:
# Epoch 1/500
# 159/159 [==============================] - 0s 1ms/step - loss: 24.9286 - val_loss: 15.0062
# Epoch 2/500
# 159/159 [==============================] - 0s 581us/step - loss: 8.9760 - val_loss: 4.2936
# Epoch 3/500
# 159/159 [==============================] - 0s 561us/step - loss: 3.4574 - val_loss: 2.6457
# Epoch 4/500
# 159/159 [==============================] - 0s 556us/step - loss: 2.2373 - val_loss: 1.8318
# Epoch 5/500
# 159/159 [==============================] - 0s 556us/step - loss: 1.5863 - val_loss: 1.2401
# Epoch 6/500
# 159/159 [==============================] - 0s 654us/step - loss: 1.1417 - val_loss: 0.8416
# Epoch 7/500
# 159/159 [==============================] - 0s 623us/step - loss: 0.8042 - val_loss: 0.5752
# Epoch 8/500
# 159/159 [==============================] - 0s 602us/step - loss: 0.5644 - val_loss: 0.3918
# Epoch 9/500
# 159/159 [==============================] - 0s 595us/step - loss: 0.4253 - val_loss: 0.2648
# Epoch 10/500
# 159/159 [==============================] - 0s 596us/step - loss: 0.2975 - val_loss: 0.1803
# Epoch 11/500
# 159/159 [==============================] - 0s 589us/step - loss: 0.2292 - val_loss: 0.1271
# Epoch 12/500
# 159/159 [==============================] - 0s 698us/step - loss: 0.1589 - val_loss: 0.0888
# Epoch 13/500
# 159/159 [==============================] - 0s 565us/step - loss: 0.1188 - val_loss: 0.0693
# Epoch 14/500
# 159/159 [==============================] - 0s 557us/step - loss: 0.1146 - val_loss: 0.0570
# Epoch 15/500
# 159/159 [==============================] - 0s 550us/step - loss: 0.0860 - val_loss: 0.0491
# Epoch 16/500
# 159/159 [==============================] - 0s 647us/step - loss: 0.0813 - val_loss: 0.0427
# Epoch 17/500
# 159/159 [==============================] - 0s 585us/step - loss: 0.0643 - val_loss: 0.0398
# Epoch 18/500
# 159/159 [==============================] - 0s 590us/step - loss: 0.0570 - val_loss: 0.0357
# Epoch 19/500
# 159/159 [==============================] - 0s 587us/step - loss: 0.0550 - val_loss: 0.0339
# Epoch 20/500
# 159/159 [==============================] - 0s 690us/step - loss: 0.0492 - val_loss: 0.0331
# Epoch 21/500
# 159/159 [==============================] - 0s 614us/step - loss: 0.0477 - val_loss: 0.0302
# Epoch 22/500
# 159/159 [==============================] - 0s 610us/step - loss: 0.0425 - val_loss: 0.0275
# Epoch 23/500
# 159/159 [==============================] - 0s 582us/step - loss: 0.0389 - val_loss: 0.0261
# Epoch 24/500
# 159/159 [==============================] - 0s 583us/step - loss: 0.0369 - val_loss: 0.0245
# Epoch 25/500
# 159/159 [==============================] - 0s 578us/step - loss: 0.0355 - val_loss: 0.0230
# Epoch 26/500
# 159/159 [==============================] - 0s 597us/step - loss: 0.0325 - val_loss: 0.0223
# Epoch 27/500
# 159/159 [==============================] - 0s 597us/step - loss: 0.0313 - val_loss: 0.0206
# Epoch 28/500
# 159/159 [==============================] - 0s 567us/step - loss: 0.0290 - val_loss: 0.0198
# Epoch 29/500
# 159/159 [==============================] - 0s 570us/step - loss: 0.0289 - val_loss: 0.0200
# Epoch 30/500
# 159/159 [==============================] - 0s 567us/step - loss: 0.0275 - val_loss: 0.0194
# Epoch 31/500
# 159/159 [==============================] - 0s 566us/step - loss: 0.0259 - val_loss: 0.0178
# Epoch 32/500
# 159/159 [==============================] - 0s 565us/step - loss: 0.0269 - val_loss: 0.0170
# Epoch 33/500
# 159/159 [==============================] - 0s 576us/step - loss: 0.0250 - val_loss: 0.0170
# Epoch 34/500
# 159/159 [==============================] - 0s 573us/step - loss: 0.0252 - val_loss: 0.0169
# Epoch 35/500
# 159/159 [==============================] - 0s 566us/step - loss: 0.0236 - val_loss: 0.0170
# Epoch 36/500
# 159/159 [==============================] - 0s 556us/step - loss: 0.0228 - val_loss: 0.0166
# Epoch 37/500
# 159/159 [==============================] - 0s 672us/step - loss: 0.0243 - val_loss: 0.0174
# Epoch 38/500
# 159/159 [==============================] - 0s 605us/step - loss: 0.0236 - val_loss: 0.0160
# Epoch 39/500
# 159/159 [==============================] - 0s 570us/step - loss: 0.0238 - val_loss: 0.0157

# %%
from sklearn.metrics import mean_squared_error

# %%
print(mean_squared_error(y_val, model.predict(X_val)))
print(mean_squared_error(y_val, lr.predict(X_val)))
# Out:
# 40/40 [==============================] - 0s 431us/step
# 0.01572929589477998
# 0.01610823614172302

# %%
# Alternatively use model.evaluate
model.evaluate(X_val, y_val)
# Out:
# 40/40 [==============================] - 0s 418us/step - loss: 0.0157
# 0.01572929508984089

# %%
## Plotting the training and validation loss
plt.figure(figsize = (8,6))
epochs = len(history.history['val_loss'])
plt.scatter(range(1, epochs + 1),history.history['loss'], label = "Training Loss")
plt.scatter(range(1, epochs + 1),history.history['val_loss'], label = "Validation Loss")

plt.xlabel("Epoch", fontsize=12)
plt.ylabel("Loss Function Value", fontsize=12)

plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

plt.legend(fontsize=12)

plt.show()

# %% [markdown]
# Once you are satisfied, check to see if the test MSE of the neural network model still beats linear regression.

# %%
from sklearn.metrics import mean_squared_error

# %%
print(model.evaluate(X_test, y_test))
print(mean_squared_error(y_test, lr.predict(X_test)))
# Out:
# 50/50 [==============================] - 0s 451us/step - loss: 0.0169
# 0.016887834295630455
# 0.017423672391001087

# %% [markdown]
# ### Forest Cover Classification Problem

# %% [markdown]
# In this problem we will build a feed forward neural network to classify forest cover type.

# %%
#!pip install ucimlrepo

# %%
# This cell took about 7 minutes to run for me!

from ucimlrepo import fetch_ucirepo 
  
# fetch dataset 
covertype = fetch_ucirepo(id=31) 
  
# data (as pandas dataframes) 
X = covertype.data.features 
y = covertype.data.targets 
  
# metadata 
print(covertype.metadata) 
  
# variable information 
print(covertype.variables)
# Out:
# {'uci_id': 31, 'name': 'Covertype', 'repository_url': 'https://archive.ics.uci.edu/dataset/31/covertype', 'data_url': 'https://archive.ics.uci.edu/static/public/31/data.csv', 'abstract': 'Classification of pixels into 7 forest cover types based on attributes such as elevation, aspect, slope, hillshade, soil-type, and more.', 'area': 'Biology', 'tasks': ['Classification'], 'characteristics': ['Multivariate'], 'num_instances': 581012, 'num_features': 54, 'feature_types': ['Categorical', 'Integer'], 'demographics': [], 'target_col': ['Cover_Type'], 'index_col': None, 'has_missing_values': 'no', 'missing_values_symbol': None, 'year_of_dataset_creation': 1998, 'last_updated': 'Sat Mar 16 2024', 'dataset_doi': '10.24432/C50K5N', 'creators': ['Jock Blackard'], 'intro_paper': None, 'additional_info': {'summary': 'Predicting forest cover type from cartographic variables only (no remotely sensed data).  The actual forest cover type for a given observation (30 x 30 meter cell) was determined from US Forest Service (USFS) Region 2 Resource Information System (RIS) data.  Independent variables were derived from data originally obtained from US Geological Survey (USGS) and USFS data.  Data is in raw form (not scaled) and contains binary (0 or 1) columns of data for qualitative independent variables (wilderness areas and soil types).\r\n\r\nThis study area includes four wilderness areas located in the Roosevelt National Forest of northern Colorado.  These areas represent forests with minimal human-caused disturbances, so that existing forest cover types are more a result of ecological processes rather than forest management practices.\r\n\r\nSome background information for these four wilderness areas: Neota (area 2) probably has the highest mean elevational value of the 4 wilderness areas. Rawah (area 1) and Comanche Peak (area 3) would have a lower mean elevational value, while Cache la Poudre (area 4) would have the lowest mean elevational value. \r\n\r\nAs for primary major tree species in these areas, Neota would have spruce/fir (type 1), while Rawah and Comanche Peak would probably have lodgepole pine (type 2) as their primary species, followed by spruce/fir and aspen (type 5). Cache la Poudre would tend to have Ponderosa pine (type 3), Douglas-fir (type 6), and cottonwood/willow (type 4).  \r\n\r\nThe Rawah and Comanche Peak areas would tend to be more typical of the overall dataset than either the Neota or Cache la Poudre, due to their assortment of tree species and range of predictive variable values (elevation, etc.)  Cache la Poudre would probably  be more unique than the others, due to its relatively low  elevation range and species composition. ', 'purpose': None, 'funded_by': None, 'instances_represent': None, 'recommended_data_splits': None, 'sensitive_data': None, 'preprocessing_description': None, 'variable_info': 'Given is the attribute name, attribute type, the measurement unit and a brief description.  The forest cover type is the classification  problem.  The order of this listing corresponds to the order of numerals along the rows of the database.\r\n\r\nName / Data Type / Measurement / Description\r\n\r\nElevation / quantitative /meters / Elevation in meters\r\nAspect / quantitative / azimuth / Aspect in degrees azimuth\r\nSlope / quantitative / degrees / Slope in degrees\r\nHorizontal_Distance_To_Hydrology / quantitative / meters / Horz Dist to nearest surface water features\r\nVertical_Distance_To_Hydrology / quantitative / meters / Vert Dist to nearest surface water features\r\nHorizontal_Distance_To_Roadways / quantitative / meters / Horz Dist to nearest roadway\r\nHillshade_9am / quantitative / 0 to 255 index / Hillshade index at 9am, summer solstice\r\nHillshade_Noon / quantitative / 0 to 255 index / Hillshade index at noon, summer soltice\r\nHillshade_3pm / quantitative / 0 to 255 index / Hillshade index at 3pm, summer solstice\r\nHorizontal_Distance_To_Fire_Points / quantitative / meters / Horz Dist to nearest w ...
#                                   name     role     type demographic  \
# 0                            Elevation  Feature  Integer        None
# 1                               Aspect  Feature  Integer        None
# 2                                Slope  Feature  Integer        None
# 3     Horizontal_Distance_To_Hydrology  Feature  Integer        None
# 4       Vertical_Distance_To_Hydrology  Feature  Integer        None
# 5      Horizontal_Distance_To_Roadways  Feature  Integer        None
# 6                        Hillshade_9am  Feature  Integer        None
# 7                       Hillshade_Noon  Feature  Integer        None
# 8                        Hillshade_3pm  Feature  Integer        None
# 9   Horizontal_Distance_To_Fire_Points  Feature  Integer        None
# 10                    Wilderness_Area1  Feature  Integer        None
# 11                          Soil_Type1  Feature  Integer        None
# 12                          Soil_Type2  Feature  Integer        None
# 13                          Soil_Type3  Feature  Integer        None
# 14                          Soil_Type4  Feature  Integer        None
# 15                          Soil_Type5  Feature  Integer        None
# 16                          Soil_Type6  Feature  Integer        None
# 17                          Soil_Type7  Feature  Integer        None
# 18                          Soil_Type8  Feature  Integer        None
# 19                          Soil_Type9  Feature  Integer        None
# 20                         Soil_Type10  Feature  Integer        None
# 21                         Soil_Type11  Feature  Integer        None
# 22                         Soil_Type12  Feature  Integer        None
# 23                         Soil_Type13  Feature  Integer        None
# 24                         Soil_Type14  Feature  Integer        None
# 25                         Soil_Type15  Feature  Integer        None
# 26                         Soil_Type16  Feature  Integer        None
# 27                         Soil_Type17  Feature  Integer        None
# 28                         Soil_Type18  Feature  Integer        None
# 29                         Soil_Type19  Feature  Integer        None
# 30                         Soil_Type20  Feature  Integer        None
# 31                         Soil_Type21  Feature  Integer        None
# 32                         Soil_Type22  Feature  Integer        None
# 33                         Soil_Type23  Feature  Integer        None
# 34                         Soil_Type24  Feature  Integer        None
# 35                         Soil_Type25  Feature  Integer        None
# 36                         Soil_Type26  Feature  Integer        None
# 37                         Soil_Type27  Feature  Integer        None
# 38                         Soil_Type28  Feature  Integer        None
# 39                         Soil_Type29  Feature  Integer        None
# 40                         Soil_Type30  Feature  Integer        None
# 41                         Soil_Type31  Feature  Integer        None
# 42                         Soil_Type32  Feature  Integer        None
# 43                         Soil_Type33  Feature  Integer        None
# 44                         Soil_Type34  Feature  Integer        None
# 45                         Soil_Type35  Feature  Integer        None
# 46                         Soil_Type36  Feature  Integer        None
# 47                         Soil_Type37  Feature  Integer        None
# 48                         Soil_Type38  Feature  Integer        None
# 49                         Soil_Type39  Feature  Integer        None
# 50                         Soil_Type40  Feature  Integer        None
# 51                          Cover_Type   Target  Integer        None
# 52                    Wilderness_Area2  Feature  Integer        None
# 53                    Wilderness_Area3  Feature  Integer        None
# 54                    Wilderness_Area4  Feature  Integer        None
#
#    description units missing_values
# 0         None  None             no
# 1         None  None             no
# 2         None  None             no
# 3         None  None             no
# 4         None  None             no
# 5         None  None             no
# 6         None  None             no
# 7         None  None             no
# 8         None  None             no
# 9         None  None             no
# 10        None  None             no
# 11        None  None             no
# 12        None  None             no
# 13        None  None             no
# 14        None  None             no
# 15        None  None             no
# 16        None  None             no
# 17        None  None             no
# 18        None  None             no
# 19        None  None             no
# 20        None  None             no
# 21        None  None             no
# 22        None  None             no
# 23        None  None             no
# 24        None  None             no
# 25        None  None             no
# 26        None  None             no
# 27        None  None             no
# 28        None  None             no
# 29        None  None             no
# 30        None  None             no
# 31        None  None             no
# 32        None  None             no
# 33        None  None             no
# 34        None  None             no
# 35        None  None             no
# 36        None  None             no
# 37        None  None             no
# 38        None  None             no
# 39        None  None             no
# 40        None  None             no
# 41        None  None             no
# 42        None  None             no
# 43        None  None             no
# 44        None  None             no
# 45        None  None             no
# 46        None  None             no
# 47        None  None             no
# 48        None  None             no
# 49        None  None             no
# 50        None  None             no
# 51        None  None             no
# 52        None  None             no
# 53        None  None             no
# 54        None  None             no

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2, random_state = 216)
X_tt, X_val, y_tt, y_val = train_test_split(X_train,y_train, test_size=0.2, random_state = 216)
X_tt.sample(5)
# Out:
#         Elevation  Aspect  Slope  Horizontal_Distance_To_Hydrology  \
# 415869       2833     184     10                               190
# 461123       3338     101     10                                30
# 343479       3334     348     19                                60
# 345480       2904     282     19                               518
# 573029       2714     238     25                               234
#
#         Vertical_Distance_To_Hydrology  Horizontal_Distance_To_Roadways  \
# 415869                              58                             1842
# 461123                              -5                             4463
# 343479                              17                             3969
# 345480                             258                             1315
# 573029                             117                             2960
#
#         Hillshade_9am  Hillshade_Noon  Hillshade_3pm  \
# 415869            222             247            157
# 461123            236             227            121
# 343479            180             204            160
# 345480            163             237            212
# 573029            166             252            215
#
#         Horizontal_Distance_To_Fire_Points  ...  Soil_Type34  Soil_Type35  \
# 415869                                2177  ...            0            0
# 461123                                4062  ...            0            0
# 343479                                 938  ...            0            0
# 345480                                1827  ...            0            0
# 573029                                1430  ...            0            0
#
#         Soil_Type36  Soil_Type37  Soil_Type38  Soil_Type39  Soil_Type40  \
# 415869            0            0            0            0            0
# 461123            0            0            0            0            0
# 343479            0            0            1            0            0
# 345480            0            0            0            0            0
# 573029            0            0            0            0            0
#
#         Wilderness_Area2  Wilderness_Area3  Wilderness_Area4
# 415869                 0                 1                 0
# 461123                 0                 1                 0
# 343479                 0                 0                 0
# 345480                 0                 1                 0
# 573029                 0                 1                 0
#
# [5 rows x 54 columns]

# %%
# Making everything into numpy arrays
X_train = X_train.values
X_tt = X_tt.values
X_val = X_val.values
X_test = X_test.values

# Adjusting class labels to go from 0 to 6 instead of 1 to 7.  Keras expects this.
y_train = y_train.values.reshape(-1) - 1
y_tt = y_tt.values.reshape(-1) - 1
y_val = y_val.values.reshape(-1) - 1
y_test = y_test.values.reshape(-1) - 1

# %% [markdown]
# Neural Networks are not a good choice for tabular data like this:  something like XGBoost is much better.  A "default settings" random forest classifier gets around 95% accuracy for this problem.
#
# The first dense feed forward NN I wrote down got 78% validation accuracy.  Can you beat that?
#
# Some things to consider:
# * Since this is a multiclass classification problem you want to use 'softmax' as your final activation function.
#     * Discussion question:  why do we need a final activation function?  Why not use 'sigmoid'?
# * Since your class labels are encoded as the integers $0,1,2,3,4,5,6$, you want to use  ['sparse_categorical_crossentropy'](https://www.tensorflow.org/api_docs/python/tf/keras/losses/sparse_categorical_crossentropy) as your loss and ['sparse_categorical_accuracy'](https://www.tensorflow.org/api_docs/python/tf/keras/metrics/sparse_categorical_accuracy) as your metric when you compile the model.

# %%
# This took about 5 minutes to run.

clf = keras.Sequential([
    layers.InputLayer(X_tt.shape[1]),
    layers.BatchNormalization(axis = -1),
    layers.Dense(20, activation = 'relu'),
    layers.Dense(20, activation = 'relu'),
    layers.Dense(7, activation =  'softmax') 
])

callback = keras.callbacks.EarlyStopping(monitor='loss', patience=3)

clf.compile(optimizer = "adam", loss = "sparse_categorical_crossentropy", metrics = 'sparse_categorical_accuracy')

history = clf.fit(X_tt, y_tt, epochs = 500, validation_data = (X_val, y_val), batch_size = 32, callbacks=[callback])
# Out:
# Epoch 1/500
# 11621/11621 [==============================] - 7s 586us/step - loss: 0.6433 - sparse_categorical_accuracy: 0.7257 - val_loss: 0.5896 - val_sparse_categorical_accuracy: 0.7530
# Epoch 2/500
# 11621/11621 [==============================] - 7s 576us/step - loss: 0.5855 - sparse_categorical_accuracy: 0.7480 - val_loss: 0.5690 - val_sparse_categorical_accuracy: 0.7619
# Epoch 3/500
# 11621/11621 [==============================] - 7s 592us/step - loss: 0.5692 - sparse_categorical_accuracy: 0.7566 - val_loss: 0.5618 - val_sparse_categorical_accuracy: 0.7648
# Epoch 4/500
# 11621/11621 [==============================] - 7s 580us/step - loss: 0.5595 - sparse_categorical_accuracy: 0.7599 - val_loss: 0.5941 - val_sparse_categorical_accuracy: 0.7728
# Epoch 5/500
# 11621/11621 [==============================] - 7s 576us/step - loss: 0.5516 - sparse_categorical_accuracy: 0.7627 - val_loss: 0.5424 - val_sparse_categorical_accuracy: 0.7789
# Epoch 6/500
# 11621/11621 [==============================] - 7s 578us/step - loss: 0.5463 - sparse_categorical_accuracy: 0.7653 - val_loss: 0.5503 - val_sparse_categorical_accuracy: 0.7796
# Epoch 7/500
# 11621/11621 [==============================] - 7s 579us/step - loss: 0.5431 - sparse_categorical_accuracy: 0.7665 - val_loss: 0.5585 - val_sparse_categorical_accuracy: 0.7782
# Epoch 8/500
# 11621/11621 [==============================] - 7s 576us/step - loss: 0.5403 - sparse_categorical_accuracy: 0.7669 - val_loss: 0.5648 - val_sparse_categorical_accuracy: 0.7799
# Epoch 9/500
# 11621/11621 [==============================] - 7s 589us/step - loss: 0.5389 - sparse_categorical_accuracy: 0.7671 - val_loss: 0.5780 - val_sparse_categorical_accuracy: 0.7778
# Epoch 10/500
# 11621/11621 [==============================] - 7s 580us/step - loss: 0.5365 - sparse_categorical_accuracy: 0.7687 - val_loss: 0.5597 - val_sparse_categorical_accuracy: 0.7851
# Epoch 11/500
# 11621/11621 [==============================] - 7s 578us/step - loss: 0.5350 - sparse_categorical_accuracy: 0.7695 - val_loss: 0.5643 - val_sparse_categorical_accuracy: 0.7841
# Epoch 12/500
# 11621/11621 [==============================] - 7s 576us/step - loss: 0.5334 - sparse_categorical_accuracy: 0.7704 - val_loss: 0.5603 - val_sparse_categorical_accuracy: 0.7852
# Epoch 13/500
# 11621/11621 [==============================] - 7s 576us/step - loss: 0.5317 - sparse_categorical_accuracy: 0.7703 - val_loss: 0.5588 - val_sparse_categorical_accuracy: 0.7843
# Epoch 14/500
# 11621/11621 [==============================] - 7s 578us/step - loss: 0.5321 - sparse_categorical_accuracy: 0.7708 - val_loss: 0.5637 - val_sparse_categorical_accuracy: 0.7841
# Epoch 15/500
# 11621/11621 [==============================] - 7s 582us/step - loss: 0.5292 - sparse_categorical_accuracy: 0.7717 - val_loss: 0.6009 - val_sparse_categorical_accuracy: 0.7802
# Epoch 16/500
# 11621/11621 [==============================] - 7s 584us/step - loss: 0.5303 - sparse_categorical_accuracy: 0.7716 - val_loss: 0.5520 - val_sparse_categorical_accuracy: 0.7844
# Epoch 17/500
# 11621/11621 [==============================] - 7s 577us/step - loss: 0.5286 - sparse_categorical_accuracy: 0.7720 - val_loss: 0.5590 - val_sparse_categorical_accuracy: 0.7878
# Epoch 18/500
# 11621/11621 [==============================] - 7s 582us/step - loss: 0.5283 - sparse_categorical_accuracy: 0.7722 - val_loss: 0.5525 - val_sparse_categorical_accuracy: 0.7910
# Epoch 19/500
# 11621/11621 [==============================] - 7s 571us/step - loss: 0.5274 - sparse_categorical_accuracy: 0.7731 - val_loss: 0.5576 - val_sparse_categorical_accuracy: 0.7882
# Epoch 20/500
# 11621/11621 [==============================] - 7s 568us/step - loss: 0.5270 - sparse_categorical_accuracy: 0.7732 - val_loss: 0.5626 - val_sparse_categorical_accuracy: 0.7906
# Epoch 21/500
# 11621/11621 [==============================] - 7s 604us/step - loss: 0.5255 - sparse_categorical_accuracy: 0.7738 - val_loss: 0.5856 - val_sparse_categorical_accuracy: 0.7831
# Epoch 22/500
# 11621/11621 [==============================] - 7s 613us/step - loss: 0.5249 - sparse_categorical_accuracy: 0.7745 - val_loss: 0.5503 - val_sparse_categorical_accuracy: 0.7902
# Epoch 23/500
# 11621/11621 [==============================] - 7s 601us/step - loss: 0.5254 - sparse_categorical_accuracy: 0.7745 - val_loss: 0.5607 - val_sparse_categorical_accuracy: 0.7874
# Epoch 24/500
# 11621/11621 [==============================] - 7s 595us/step - loss: 0.5248 - sparse_categorical_accuracy: 0.7748 - val_loss: 0.5740 - val_sparse_categorical_accuracy: 0.7878
# Epoch 25/500
# 11621/11621 [==============================] - 7s 599us/step - loss: 0.5242 - sparse_categorical_accuracy: 0.7745 - val_loss: 0.5428 - val_sparse_categorical_accuracy: 0.7901
# Epoch 26/500
# 11621/11621 [==============================] - 7s 606us/step - loss: 0.5241 - sparse_categorical_accuracy: 0.7750 - val_loss: 0.5481 - val_sparse_categorical_accuracy: 0.7875
# Epoch 27/500
# 11621/11621 [==============================] - 7s 638us/step - loss: 0.5230 - sparse_categorical_accuracy: 0.7752 - val_loss: 0.5648 - val_sparse_categorical_accuracy: 0.7874
# Epoch 28/500
# 11621/11621 [==============================] - 7s 645us/step - loss: 0.5226 - sparse_categorical_accuracy: 0.7751 - val_loss: 0.5593 - val_sparse_categorical_accuracy: 0.7834
# Epoch 29/500
# 11621/11621 [==============================] - 7s 625us/step - loss: 0.5240 - sparse_categorical_accuracy: 0.7747 - val_loss: 0.5519 - val_sparse_categorical_accuracy: 0.7866
# Epoch 30/500
# 11621/11621 [==============================] - 7s 619us/step - loss: 0.5234 - sparse_categorical_accuracy: 0.7750 - val_loss: 0.5715 - val_sparse_categorical_accuracy: 0.7849
# Epoch 31/500
# 11621/11621 [==============================] - 7s 597us/step - loss: 0.5218 - sparse_categorical_accuracy: 0.7758 - val_loss: 0.5523 - val_sparse_categorical_accuracy: 0.7869
# Epoch 32/500
# 11621/11621 [==============================] - 7s 607us/step - loss: 0.5222 - sparse_categorical_accuracy: 0.7757 - val_loss: 0.5583 - val_sparse_categorical_accuracy: 0.7903
# Epoch 33/500
# 11621/11621 [==============================] - 7s 606us/step - loss: 0.5211 - sparse_categorical_accuracy: 0.7766 - val_loss: 0.5632 - val_sparse_categorical_accuracy: 0.7841
# Epoch 34/500
# 11621/11621 [==============================] - 7s 599us/step - loss: 0.5219 - sparse_categorical_accuracy: 0.7751 - val_loss: 0.5524 - val_sparse_categorical_accuracy: 0.7843
# Epoch 35/500
# 11621/11621 [==============================] - 7s 603us/step - loss: 0.5211 - sparse_categorical_accuracy: 0.7762 - val_loss: 0.5550 - val_sparse_categorical_accuracy: 0.7868
# Epoch 36/500
# 11621/11621 [==============================] - 7s 586us/step - loss: 0.5206 - sparse_categorical_accuracy: 0.7761 - val_loss: 0.5610 - val_sparse_categorical_accuracy: 0.7861
# Epoch 37/500
# 11621/11621 [==============================] - 7s 590us/step - loss: 0.5211 - sparse_categorical_accuracy: 0.7763 - val_loss: 0.5586 - val_sparse_categorical_accuracy: 0.7882
# Epoch 38/500
# 11621/11621 [==============================] - 7s 579us/step - loss: 0.5201 - sparse_categorical_accuracy: 0.7768 - val_loss: 0.5685 - val_sparse_categorical_accuracy: 0.7837
# Epoch 39/500
# 11621/11621 [==============================] - 7s 582us/step - loss: 0.5208 - sparse_categorical_accuracy: 0.7767 - val_loss: 0.5352 - val_sparse_categorical_accuracy: 0.7936
# Epoch 40/500
# 11621/11621 [==============================] - 7s 579us/step - loss: 0.5206 - sparse_categorical_accuracy: 0.7766 - val_loss: 0.5450 - val_sparse_categorical_accuracy: 0.7897
# Epoch 41/500
# 11621/11621 [==============================] - 7s 593us/step - loss: 0.5202 - sparse_categorical_accuracy: 0.7768 - val_loss: 0.5430 - val_sparse_categorical_accuracy: 0.7871

# %%
clf.evaluate(X_val, y_val.reshape(-1) )
# Out:
# 2906/2906 [==============================] - 1s 370us/step - loss: 0.5430 - sparse_categorical_accuracy: 0.7871
# [0.5429797172546387, 0.7870957851409912]

# %%
clf.evaluate(X_test, y_test.reshape(-1) )
# Out:
# 3632/3632 [==============================] - 1s 354us/step - loss: 0.5443 - sparse_categorical_accuracy: 0.7834
# [0.5443335771560669, 0.7833532691001892]
